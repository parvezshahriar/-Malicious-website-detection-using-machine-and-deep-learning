# %% [markdown]
# <a href="https://colab.research.google.com/github/parvezshahriar/-Malicious-website-detection-using-machine-and-deep-learning/blob/main/Untitled34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install polars

# %%
import polars as pl

# %%
import csv
import random
from datetime import datetime,timedelta

# %%
columns=["transaction_id","customer_id","amount","transaction_date"]

# %%
rows=[]
start_date=datetime(2023,1,1)
for i in range(1,1001):
  customer_id=random.randint(1,100)
  amount=random.uniform(10,1000)
  date=start_date+timedelta(days=random.randint(0,365))
  rows.append([i,customer_id,amount,date.strftime("%Y-%m-%d")])

# %%
with open('transactions.csv','w',newline='') as file:
  writer=csv.writer(file)
  writer.writerow(columns)
  writer.writerows(rows)

# %%
pl.read_csv('transactions.csv').head()
# Out:
# shape: (5, 4)
# ┌────────────────┬─────────────┬────────────┬──────────────────┐
# │ transaction_id ┆ customer_id ┆ amount     ┆ transaction_date │
# │ ---            ┆ ---         ┆ ---        ┆ ---              │
# │ i64            ┆ i64         ┆ f64        ┆ str              │
# ╞════════════════╪═════════════╪════════════╪══════════════════╡
# │ 1              ┆ 99          ┆ 584.782369 ┆ 2023-10-31       │
# │ 2              ┆ 1           ┆ 81.723155  ┆ 2023-04-01       │
# │ 3              ┆ 46          ┆ 961.006546 ┆ 2023-03-17       │
# │ 4              ┆ 62          ┆ 404.497176 ┆ 2023-07-10       │
# │ 5              ┆ 59          ┆ 130.551313 ┆ 2023-01-21       │
# └────────────────┴─────────────┴────────────┴──────────────────┘
